# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | goderich
# Processing Record 2 of Set 1 | vallenar
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | saint-agapit
# Processing Record 10 of Set 1 | nehe
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | souillac
# Processing Record 13 of Set 1 | balabac
# Processing Record 14 of Set 1 | tuatapere
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | isiolo
# Processing Record 17 of Set 1 | chapais
# Processing Record 18 of Set 1 | bathsheba
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 1 | broome
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | dodoma
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | laguna
# Processing Record 28 of Set 1 | sorland
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | yerbogachen
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | ekimchan
# Processing Record 33 of Set 1 | port blair
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | cap malheureux
# Processing Record 38 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | pangnirtung
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | fort nelson
# Processing Record 43 of Set 1 | kiunga
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | manado
# Processing Record 48 of Set 1 | benguela
# Processing Record 49 of Set 1 | iwanai
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | kloulklubed
# Processing Record 2 of Set 2 | xining
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | itoman
# Processing Record 6 of Set 2 | luderitz
# Processing Record 7 of Set 2 | clarence town
# Processing Record 8 of Set 2 | gazimurskiy zavod
# Processing Record 9 of Set 2 | coihaique
# Processing Record 10 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 2 | kerrville
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | vestmannaeyjar
# Processing Record 14 of Set 2 | isangel
# Processing Record 15 of Set 2 | rochegda
# Processing Record 16 of Set 2 | cuaspud
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | poum
# Processing Record 19 of Set 2 | gazanjyk
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | simao
# Processing Record 22 of Set 2 | uaua
# Processing Record 23 of Set 2 | lingao
# Processing Record 24 of Set 2 | susurluk
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | esmeraldas
# Processing Record 27 of Set 2 | colares
# Processing Record 28 of Set 2 | makat
# Processing Record 29 of Set 2 | kulhudhuffushi
# Processing Record 30 of Set 2 | cabedelo
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | nanortalik
# Processing Record 34 of Set 2 | rio grande
# Processing Record 35 of Set 2 | balykshi
# Processing Record 36 of Set 2 | hirara
# Processing Record 37 of Set 2 | constitucion
# Processing Record 38 of Set 2 | sao filipe
# Processing Record 39 of Set 2 | lorengau
# Processing Record 40 of Set 2 | mahibadhoo
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 2 | san cristobal
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 49 of Set 2 | olinda
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | belaya gora
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | waingapu
# Processing Record 4 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | meulaboh
# Processing Record 12 of Set 3 | skjervoy
# Processing Record 13 of Set 3 | abeche
# Processing Record 14 of Set 3 | hailey
# Processing Record 15 of Set 3 | leshukonskoye
# Processing Record 16 of Set 3 | cape town
# Processing Record 17 of Set 3 | denpasar
# Processing Record 18 of Set 3 | airai
# Processing Record 19 of Set 3 | neyshabur
# Processing Record 20 of Set 3 | arraial do cabo
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | pryazha
# Processing Record 24 of Set 3 | tubuala
# Processing Record 25 of Set 3 | qasigiannguit
# Processing Record 26 of Set 3 | seoul
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | ganzhou
# Processing Record 29 of Set 3 | muhos
# Processing Record 30 of Set 3 | husavik
# Processing Record 31 of Set 3 | jacareacanga
# Processing Record 32 of Set 3 | korla
# Processing Record 33 of Set 3 | busselton
# Processing Record 34 of Set 3 | urzhum
# Processing Record 35 of Set 3 | saldanha
# Processing Record 36 of Set 3 | vaini
# Processing Record 37 of Set 3 | cherskiy
# Processing Record 38 of Set 3 | clinton
# Processing Record 39 of Set 3 | hithadhoo
# Processing Record 40 of Set 3 | eyl
# Processing Record 41 of Set 3 | fortuna
# Processing Record 42 of Set 3 | chicama
# Processing Record 43 of Set 3 | quatre cocos
# Processing Record 44 of Set 3 | zvishavane
# Processing Record 45 of Set 3 | ganta
# Processing Record 46 of Set 3 | bilibino
# Processing Record 47 of Set 3 | hofn
# Processing Record 48 of Set 3 | turtas
# Processing Record 49 of Set 3 | awbari
# Processing Record 50 of Set 3 | rocha
# Processing Record 1 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 4 | jaru
# Processing Record 3 of Set 4 | kaka
# Processing Record 4 of Set 4 | port hedland
# Processing Record 5 of Set 4 | srednekolymsk
# Processing Record 6 of Set 4 | bossier city
# Processing Record 7 of Set 4 | tasiilaq
# Processing Record 8 of Set 4 | ocosingo
# Processing Record 9 of Set 4 | san policarpo
# Processing Record 10 of Set 4 | bodden town
# Processing Record 11 of Set 4 | hauterive
# Processing Record 12 of Set 4 | timra
# Processing Record 13 of Set 4 | avera
# Processing Record 14 of Set 4 | olean
# Processing Record 15 of Set 4 | saint george
# Processing Record 16 of Set 4 | ndele
# Processing Record 17 of Set 4 | nikolskoye
# Processing Record 18 of Set 4 | ust-tsilma
# Processing Record 19 of Set 4 | ancud
# Processing Record 20 of Set 4 | dingle
# Processing Record 21 of Set 4 | kisangani
# Processing Record 22 of Set 4 | maceio
# Processing Record 23 of Set 4 | port augusta
# Processing Record 24 of Set 4 | port macquarie
# Processing Record 25 of Set 4 | vila franca do campo
# Processing Record 26 of Set 4 | belmonte
# Processing Record 27 of Set 4 | rock springs
# Processing Record 28 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 4 | qaqortoq
# Processing Record 30 of Set 4 | sao felix do xingu
# Processing Record 31 of Set 4 | evensk
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | trairi
# Processing Record 34 of Set 4 | xichang
# Processing Record 35 of Set 4 | jumla
# Processing Record 36 of Set 4 | smithers
# Processing Record 37 of Set 4 | port alfred
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | quesnel
# Processing Record 40 of Set 4 | katsuura
# Processing Record 41 of Set 4 | mach
# Processing Record 42 of Set 4 | ahipara
# Processing Record 43 of Set 4 | corinto
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 4 | lagoa
# Processing Record 47 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 4 | cabo san lucas
# Processing Record 49 of Set 4 | margate
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | kenai
# Processing Record 2 of Set 5 | narsaq
# Processing Record 3 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 5 | katha
# City not found. Skipping...
# Processing Record 5 of Set 5 | salalah
# Processing Record 6 of Set 5 | brae
# Processing Record 7 of Set 5 | samarai
# Processing Record 8 of Set 5 | dosso
# Processing Record 9 of Set 5 | kayes
# Processing Record 10 of Set 5 | dalvik
# Processing Record 11 of Set 5 | hambantota
# Processing Record 12 of Set 5 | trutnov
# Processing Record 13 of Set 5 | cayenne
# Processing Record 14 of Set 5 | mahajanga
# Processing Record 15 of Set 5 | eureka
# Processing Record 16 of Set 5 | monze
# Processing Record 17 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | beloha
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | tadine
# Processing Record 22 of Set 5 | nemuro
# Processing Record 23 of Set 5 | mar del plata
# Processing Record 24 of Set 5 | georgetown
# Processing Record 25 of Set 5 | miguel pereira
# Processing Record 26 of Set 5 | kaitangata
# Processing Record 27 of Set 5 | teruel
# Processing Record 28 of Set 5 | bilma
# Processing Record 29 of Set 5 | severnoye
# Processing Record 30 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 5 | victoria
# Processing Record 32 of Set 5 | isla vista
# Processing Record 33 of Set 5 | clyde river
# Processing Record 34 of Set 5 | aldan
# Processing Record 35 of Set 5 | wilmington
# Processing Record 36 of Set 5 | turbat
# Processing Record 37 of Set 5 | kazuno
# Processing Record 38 of Set 5 | dalbandin
# Processing Record 39 of Set 5 | sept-iles
# Processing Record 40 of Set 5 | vaitape
# Processing Record 41 of Set 5 | bandarbeyla
# Processing Record 42 of Set 5 | carira
# Processing Record 43 of Set 5 | teya
# Processing Record 44 of Set 5 | iqaluit
# Processing Record 45 of Set 5 | sur
# Processing Record 46 of Set 5 | severo-kurilsk
# Processing Record 47 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 5 | lerwick
# Processing Record 49 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 50 of Set 5 | iquitos
# Processing Record 1 of Set 6 | padang
# Processing Record 2 of Set 6 | nome
# Processing Record 3 of Set 6 | kismayo
# Processing Record 4 of Set 6 | staraya poltavka
# Processing Record 5 of Set 6 | kerchevskiy
# Processing Record 6 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 7 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 6 | buzuluk
# Processing Record 9 of Set 6 | hami
# Processing Record 10 of Set 6 | guerrero negro
# Processing Record 11 of Set 6 | armidale
# Processing Record 12 of Set 6 | pueblo
# Processing Record 13 of Set 6 | sosnovo-ozerskoye
# Processing Record 14 of Set 6 | freetown
# Processing Record 15 of Set 6 | kamaishi
# Processing Record 16 of Set 6 | karratha
# Processing Record 17 of Set 6 | ostrovnoy
# Processing Record 18 of Set 6 | tawau
# Processing Record 19 of Set 6 | pudsey
# Processing Record 20 of Set 6 | haines junction
# Processing Record 21 of Set 6 | krasnoarmeysk
# Processing Record 22 of Set 6 | andenes
# Processing Record 23 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 25 of Set 6 | chokurdakh
# Processing Record 26 of Set 6 | malinyi
# Processing Record 27 of Set 6 | hasaki
# Processing Record 28 of Set 6 | bima
# Processing Record 29 of Set 6 | arlit
# Processing Record 30 of Set 6 | beringovskiy
# Processing Record 31 of Set 6 | fairbanks
# Processing Record 32 of Set 6 | half moon bay
# Processing Record 33 of Set 6 | puerto madryn
# Processing Record 34 of Set 6 | ilhabela
# Processing Record 35 of Set 6 | erechim
# Processing Record 36 of Set 6 | belgrade
# Processing Record 37 of Set 6 | macia
# Processing Record 38 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 39 of Set 6 | faridan
# City not found. Skipping...
# Processing Record 40 of Set 6 | ayan
# Processing Record 41 of Set 6 | novi sanzhary
# Processing Record 42 of Set 6 | hovd
# Processing Record 43 of Set 6 | homer
# Processing Record 44 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 6 | saint-leu
# Processing Record 46 of Set 6 | neuquen
# Processing Record 47 of Set 6 | san isidro
# Processing Record 48 of Set 6 | constantine
# Processing Record 49 of Set 6 | sitka
# Processing Record 50 of Set 6 | tapes
# Processing Record 1 of Set 7 | champerico
# Processing Record 2 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 3 of Set 7 | butembo
# Processing Record 4 of Set 7 | chimbote
# Processing Record 5 of Set 7 | alofi
# Processing Record 6 of Set 7 | idrinskoye
# Processing Record 7 of Set 7 | sigiriya
# Processing Record 8 of Set 7 | chekhov
# Processing Record 9 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 7 | fare
# Processing Record 11 of Set 7 | inhambane
# Processing Record 12 of Set 7 | gold coast
# Processing Record 13 of Set 7 | saint-joseph
# Processing Record 14 of Set 7 | upernavik
# Processing Record 15 of Set 7 | vila
# Processing Record 16 of Set 7 | palmer
# Processing Record 17 of Set 7 | kabanjahe
# Processing Record 18 of Set 7 | zemio
# Processing Record 19 of Set 7 | bereda
# Processing Record 20 of Set 7 | catuday
# Processing Record 21 of Set 7 | innisfail
# Processing Record 22 of Set 7 | ihosy
# Processing Record 23 of Set 7 | carutapera
# Processing Record 24 of Set 7 | victor harbor
# Processing Record 25 of Set 7 | plainview
# Processing Record 26 of Set 7 | faya
# Processing Record 27 of Set 7 | xalpatlahuac
# Processing Record 28 of Set 7 | humaita
# Processing Record 29 of Set 7 | tommot
# Processing Record 30 of Set 7 | presidencia roque saenz pena
# Processing Record 31 of Set 7 | chokwe
# Processing Record 32 of Set 7 | oktyabrskoye
# Processing Record 33 of Set 7 | firozabad
# Processing Record 34 of Set 7 | effium
# Processing Record 35 of Set 7 | san carlos de bariloche
# Processing Record 36 of Set 7 | friockheim
# Processing Record 37 of Set 7 | codrington
# Processing Record 38 of Set 7 | valdez
# Processing Record 39 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 7 | geraldton
# Processing Record 41 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 42 of Set 7 | paducah
# Processing Record 43 of Set 7 | esperance
# Processing Record 44 of Set 7 | lavrentiya
# Processing Record 45 of Set 7 | the valley
# Processing Record 46 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 47 of Set 7 | sosnovka
# Processing Record 48 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 7 | porto novo
# Processing Record 50 of Set 7 | sikasso
# Processing Record 1 of Set 8 | solnechnyy
# Processing Record 2 of Set 8 | bantva
# Processing Record 3 of Set 8 | coquimbo
# Processing Record 4 of Set 8 | kurchum
# Processing Record 5 of Set 8 | balkhash
# Processing Record 6 of Set 8 | great yarmouth
# Processing Record 7 of Set 8 | lhokseumawe
# Processing Record 8 of Set 8 | novopokrovka
# Processing Record 9 of Set 8 | abu zabad
# Processing Record 10 of Set 8 | vrangel
# Processing Record 11 of Set 8 | okha
# Processing Record 12 of Set 8 | te anau
# Processing Record 13 of Set 8 | uchiza
# Processing Record 14 of Set 8 | kurush
# Processing Record 15 of Set 8 | grand-lahou
# Processing Record 16 of Set 8 | olafsvik
# Processing Record 17 of Set 8 | hobyo
# Processing Record 18 of Set 8 | anadyr
# Processing Record 19 of Set 8 | port moresby
# Processing Record 20 of Set 8 | roebourne
# Processing Record 21 of Set 8 | nebolchi
# Processing Record 22 of Set 8 | monrovia
# Processing Record 23 of Set 8 | baghdad
# Processing Record 24 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 8 | pasighat
# Processing Record 26 of Set 8 | campbell river
# Processing Record 27 of Set 8 | puerto escondido
# Processing Record 28 of Set 8 | tak bai
# Processing Record 29 of Set 8 | yaan
# Processing Record 30 of Set 8 | najran
# Processing Record 31 of Set 8 | egvekinot
# Processing Record 32 of Set 8 | manavalakurichi
# Processing Record 33 of Set 8 | mianyang
# Processing Record 34 of Set 8 | tilichiki
# Processing Record 35 of Set 8 | mbala
# Processing Record 36 of Set 8 | kavieng
# Processing Record 37 of Set 8 | upington
# Processing Record 38 of Set 8 | mount gambier
# Processing Record 39 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 8 | maningrida
# Processing Record 41 of Set 8 | sandy bay
# Processing Record 42 of Set 8 | manta
# Processing Record 43 of Set 8 | zhaocheng
# City not found. Skipping...
# Processing Record 44 of Set 8 | kuala terengganu
# Processing Record 45 of Set 8 | ponta delgada
# Processing Record 46 of Set 8 | rio gallegos
# Processing Record 47 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 8 | kahului
# Processing Record 49 of Set 8 | merauke
# Processing Record 50 of Set 8 | borogontsy
# Processing Record 1 of Set 9 | de-kastri
# Processing Record 2 of Set 9 | dudinka
# Processing Record 3 of Set 9 | kuusamo
# Processing Record 4 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 9 | bara
# Processing Record 6 of Set 9 | kupang
# Processing Record 7 of Set 9 | huilong
# Processing Record 8 of Set 9 | selma
# Processing Record 9 of Set 9 | conroe
# Processing Record 10 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 9 | vadastrita
# Processing Record 12 of Set 9 | flinders
# Processing Record 13 of Set 9 | tual
# Processing Record 14 of Set 9 | muros
# Processing Record 15 of Set 9 | maymyo
# Processing Record 16 of Set 9 | owando
# Processing Record 17 of Set 9 | freeport
# Processing Record 18 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 9 | tabuk
# Processing Record 20 of Set 9 | mayo
# Processing Record 21 of Set 9 | bebra
# Processing Record 22 of Set 9 | aragarcas
# Processing Record 23 of Set 9 | jamame
# Processing Record 24 of Set 9 | nazare
# Processing Record 25 of Set 9 | pacific grove
# Processing Record 26 of Set 9 | harper
# Processing Record 27 of Set 9 | ocos
# Processing Record 28 of Set 9 | muisne
# Processing Record 29 of Set 9 | noumea
# Processing Record 30 of Set 9 | chabahar
# Processing Record 31 of Set 9 | lisakovsk
# Processing Record 32 of Set 9 | mae hong son
# Processing Record 33 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 9 | sambava
# Processing Record 35 of Set 9 | ginda
# Processing Record 36 of Set 9 | zyryanka
# Processing Record 37 of Set 9 | teocaltiche
# Processing Record 38 of Set 9 | leningradskiy
# Processing Record 39 of Set 9 | pevek
# Processing Record 40 of Set 9 | waddan
# Processing Record 41 of Set 9 | riyadh
# Processing Record 42 of Set 9 | yatou
# Processing Record 43 of Set 9 | vangaindrano
# Processing Record 44 of Set 9 | kibala
# Processing Record 45 of Set 9 | vestmanna
# Processing Record 46 of Set 9 | san quintin
# Processing Record 47 of Set 9 | bella union
# Processing Record 48 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 9 | yilan
# Processing Record 50 of Set 9 | luwuk
# Processing Record 1 of Set 10 | antalaha
# Processing Record 2 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 10 | buluang
# Processing Record 4 of Set 10 | labuhan
# Processing Record 5 of Set 10 | mangaldai
# Processing Record 6 of Set 10 | comodoro rivadavia
# Processing Record 7 of Set 10 | ust-uda
# Processing Record 8 of Set 10 | wonogiri
# Processing Record 9 of Set 10 | san pedro
# Processing Record 10 of Set 10 | vila velha
# Processing Record 11 of Set 10 | chiplun
# Processing Record 12 of Set 10 | yelets
# Processing Record 13 of Set 10 | aksay
# Processing Record 14 of Set 10 | luanda
# Processing Record 15 of Set 10 | bossembele
# City not found. Skipping...
# Processing Record 16 of Set 10 | kambove
# Processing Record 17 of Set 10 | varniai
# Processing Record 18 of Set 10 | walvis bay
# Processing Record 19 of Set 10 | ugoofaaru
# Processing Record 20 of Set 10 | nabire
# Processing Record 21 of Set 10 | tautira
# Processing Record 22 of Set 10 | pacifica
# Processing Record 23 of Set 10 | spokane
# Processing Record 24 of Set 10 | greensburg
# Processing Record 25 of Set 10 | xai-xai
# Processing Record 26 of Set 10 | castrillon
# Processing Record 27 of Set 10 | price
# Processing Record 28 of Set 10 | yulara
# Processing Record 29 of Set 10 | sao jose da coroa grande
# Processing Record 30 of Set 10 | abu samrah
# Processing Record 31 of Set 10 | yar-sale
# Processing Record 32 of Set 10 | sale
# Processing Record 33 of Set 10 | subaytilah
# City not found. Skipping...
# Processing Record 34 of Set 10 | horizontina
# Processing Record 35 of Set 10 | alice springs
# Processing Record 36 of Set 10 | mana
# Processing Record 37 of Set 10 | exeter
# Processing Record 38 of Set 10 | talara
# Processing Record 39 of Set 10 | irgakly
# Processing Record 40 of Set 10 | christchurch
# Processing Record 41 of Set 10 | los llanos de aridane
# Processing Record 42 of Set 10 | tres arroyos
# Processing Record 43 of Set 10 | lata
# Processing Record 44 of Set 10 | lalmohan
# Processing Record 45 of Set 10 | madimba
# Processing Record 46 of Set 10 | lalibela
# Processing Record 47 of Set 10 | marzuq
# Processing Record 48 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 10 | berdigestyakh
# Processing Record 50 of Set 10 | toila
# Processing Record 1 of Set 11 | stokmarknes
# Processing Record 2 of Set 11 | simnas
# Processing Record 3 of Set 11 | richards bay
# Processing Record 4 of Set 11 | obluche
# City not found. Skipping...
# Processing Record 5 of Set 11 | sola
# Processing Record 6 of Set 11 | vardo
# Processing Record 7 of Set 11 | henties bay
# Processing Record 8 of Set 11 | tongchuan
# Processing Record 9 of Set 11 | sretensk
# Processing Record 10 of Set 11 | atambua
# Processing Record 11 of Set 11 | saint-louis
# Processing Record 12 of Set 11 | bay roberts
# Processing Record 13 of Set 11 | cervo
# Processing Record 14 of Set 11 | gobabis
# Processing Record 15 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 11 | jiaozuo
# Processing Record 17 of Set 11 | stepantsevo
# Processing Record 18 of Set 11 | northam
# Processing Record 19 of Set 11 | caravelas
# Processing Record 20 of Set 11 | rock falls
# Processing Record 21 of Set 11 | tabory
# Processing Record 22 of Set 11 | inuvik
# Processing Record 23 of Set 11 | kikwit
# Processing Record 24 of Set 11 | nieves
# Processing Record 25 of Set 11 | kampot
# Processing Record 26 of Set 11 | jansath
# Processing Record 27 of Set 11 | baie-comeau
# Processing Record 28 of Set 11 | kungsbacka
# Processing Record 29 of Set 11 | erzin
# Processing Record 30 of Set 11 | oktyabrskiy
# Processing Record 31 of Set 11 | eydhafushi
# Processing Record 32 of Set 11 | necochea
# Processing Record 33 of Set 11 | adrar
# Processing Record 34 of Set 11 | saint andrews
# Processing Record 35 of Set 11 | assen
# Processing Record 36 of Set 11 | halifax
# Processing Record 37 of Set 11 | marathokambos
# City not found. Skipping...
# Processing Record 38 of Set 11 | wisconsin rapids
# Processing Record 39 of Set 11 | crowley
# Processing Record 40 of Set 11 | san patricio
# Processing Record 41 of Set 11 | bose
# Processing Record 42 of Set 11 | huarmey
# Processing Record 43 of Set 11 | kalmunai
# Processing Record 44 of Set 11 | raudeberg
# Processing Record 45 of Set 11 | iskateley
# Processing Record 46 of Set 11 | tekax
# City not found. Skipping...
# Processing Record 47 of Set 11 | owase
# Processing Record 48 of Set 11 | namatanai
# Processing Record 49 of Set 11 | shimoda
# Processing Record 50 of Set 11 | ontario
# Processing Record 1 of Set 12 | namtsy
# Processing Record 2 of Set 12 | grindavik
# Processing Record 3 of Set 12 | cockburn town
# Processing Record 4 of Set 12 | rusne
# Processing Record 5 of Set 12 | altamont
# Processing Record 6 of Set 12 | monoharpur
# Processing Record 7 of Set 12 | sobolevo
# Processing Record 8 of Set 12 | manggar
# Processing Record 9 of Set 12 | zaysan
# Processing Record 10 of Set 12 | praia da vitoria
# Processing Record 11 of Set 12 | rawson
# Processing Record 12 of Set 12 | mapiripan
# Processing Record 13 of Set 12 | malinovoye ozero
# Processing Record 14 of Set 12 | jaitaran
# Processing Record 15 of Set 12 | marawi
# Processing Record 16 of Set 12 | buchanan
# Processing Record 17 of Set 12 | nueve de julio
# Processing Record 18 of Set 12 | kang
# Processing Record 19 of Set 12 | karla
# Processing Record 20 of Set 12 | syava
# Processing Record 21 of Set 12 | lundamo
# Processing Record 22 of Set 12 | north myrtle beach
# Processing Record 23 of Set 12 | hellvik
# Processing Record 24 of Set 12 | hualmay
# Processing Record 25 of Set 12 | ilulissat
# Processing Record 26 of Set 12 | kamina
# Processing Record 27 of Set 12 | trelew
# Processing Record 28 of Set 12 | makakilo city
# Processing Record 29 of Set 12 | xiaoweizhai
# Processing Record 30 of Set 12 | nyagan
# Processing Record 31 of Set 12 | chadan
# Processing Record 32 of Set 12 | berlevag
# Processing Record 33 of Set 12 | karasjok
# Processing Record 34 of Set 12 | maun
# Processing Record 35 of Set 12 | zhangjiakou
# Processing Record 36 of Set 12 | liverpool
# Processing Record 37 of Set 12 | lashio
# Processing Record 38 of Set 12 | san clemente
# Processing Record 39 of Set 12 | kearney
# Processing Record 40 of Set 12 | abalak
# Processing Record 41 of Set 12 | pemangkat
# Processing Record 42 of Set 12 | hjelset
# Processing Record 43 of Set 12 | kijang
# Processing Record 44 of Set 12 | elko
# Processing Record 45 of Set 12 | ascension
# Processing Record 46 of Set 12 | corn island
# Processing Record 47 of Set 12 | yining
# Processing Record 48 of Set 12 | noshiro
# Processing Record 49 of Set 12 | waiouru
# Processing Record 50 of Set 12 | ceres
# Processing Record 1 of Set 13 | shuya
# Processing Record 2 of Set 13 | provideniya
# Processing Record 3 of Set 13 | inirida
# Processing Record 4 of Set 13 | mongo
# Processing Record 5 of Set 13 | maldonado
# Processing Record 6 of Set 13 | asyut
# Processing Record 7 of Set 13 | kuching
# Processing Record 8 of Set 13 | mailani
# Processing Record 9 of Set 13 | sabya
# Processing Record 10 of Set 13 | zhigansk
# Processing Record 11 of Set 13 | ojinaga
# Processing Record 12 of Set 13 | saint anthony
# Processing Record 13 of Set 13 | corrales
# Processing Record 14 of Set 13 | tazovskiy
# Processing Record 15 of Set 13 | kuopio
# Processing Record 16 of Set 13 | nara
# Processing Record 17 of Set 13 | goteborg
# City not found. Skipping...
# Processing Record 18 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 13 | sorong
# Processing Record 20 of Set 13 | santa cruz
# Processing Record 21 of Set 13 | kabalo
# Processing Record 22 of Set 13 | greymouth
# Processing Record 23 of Set 13 | sibolga
# Processing Record 24 of Set 13 | komsomolskiy
# Processing Record 25 of Set 13 | rapid valley
# Processing Record 26 of Set 13 | lasa
# Processing Record 27 of Set 13 | maniitsoq
# Processing Record 28 of Set 13 | coxim
# Processing Record 29 of Set 13 | cody
# Processing Record 30 of Set 13 | daru
# Processing Record 31 of Set 13 | wagar
# Processing Record 32 of Set 13 | dustlik
# Processing Record 33 of Set 13 | limon
# Processing Record 34 of Set 13 | gilgit
# Processing Record 35 of Set 13 | novikovo
# Processing Record 36 of Set 13 | opobo
# City not found. Skipping...
# Processing Record 37 of Set 13 | pisco
# Processing Record 38 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 39 of Set 13 | prata
# Processing Record 40 of Set 13 | mount isa
# Processing Record 41 of Set 13 | dubbo
# Processing Record 42 of Set 13 | ahuimanu
# Processing Record 43 of Set 13 | barra
# Processing Record 44 of Set 13 | palauig
# Processing Record 45 of Set 13 | hakkari
# Processing Record 46 of Set 13 | itarema
# Processing Record 47 of Set 13 | surovatikha
# Processing Record 48 of Set 13 | kudahuvadhoo
# Processing Record 49 of Set 13 | stryn
# Processing Record 50 of Set 13 | miri
# Processing Record 1 of Set 14 | khabary
# Processing Record 2 of Set 14 | ha tinh
# Processing Record 3 of Set 14 | dolores
# Processing Record 4 of Set 14 | bulawayo
# Processing Record 5 of Set 14 | kibondo
# Processing Record 6 of Set 14 | isabela
# Processing Record 7 of Set 14 | ulladulla
# Processing Record 8 of Set 14 | saint-marc
# Processing Record 9 of Set 14 | acarau
# Processing Record 10 of Set 14 | bosaso
# Processing Record 11 of Set 14 | tagusao
# Processing Record 12 of Set 14 | sao miguel do araguaia
# Processing Record 13 of Set 14 | rognan
# Processing Record 14 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 14 | houma
# Processing Record 16 of Set 14 | broken hill
# Processing Record 17 of Set 14 | jomalig
# City not found. Skipping...
# Processing Record 18 of Set 14 | omboue
# Processing Record 19 of Set 14 | ixtapa
# Processing Record 20 of Set 14 | calabozo
# Processing Record 21 of Set 14 | siparia
# Processing Record 22 of Set 14 | sinnamary
# Processing Record 23 of Set 14 | pangkalanbuun
# Processing Record 24 of Set 14 | noisy-le-grand
# Processing Record 25 of Set 14 | bubaque
# Processing Record 26 of Set 14 | panama city
# Processing Record 27 of Set 14 | acapulco
# Processing Record 28 of Set 14 | otane
# Processing Record 29 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 14 | sfantu gheorghe
# Processing Record 31 of Set 14 | tezu
# Processing Record 32 of Set 14 | placido de castro
# Processing Record 33 of Set 14 | urengoy
# Processing Record 34 of Set 14 | qandala
# Processing Record 35 of Set 14 | sao luis de montes belos
# Processing Record 36 of Set 14 | tignere
# Processing Record 37 of Set 14 | mobile
# Processing Record 38 of Set 14 | pontalina
# Processing Record 39 of Set 14 | aklavik
# Processing Record 40 of Set 14 | snina
# Processing Record 41 of Set 14 | masuguru
# Processing Record 42 of Set 14 | gander
# Processing Record 43 of Set 14 | arinos
# Processing Record 44 of Set 14 | swan hill
# Processing Record 45 of Set 14 | salamiyah
# Processing Record 46 of Set 14 | aswan
# Processing Record 47 of Set 14 | durban
# Processing Record 48 of Set 14 | kerman
# Processing Record 49 of Set 14 | pundaguitan
# Processing Record 50 of Set 14 | marathon
# Processing Record 1 of Set 15 | san rafael
# Processing Record 2 of Set 15 | tres lagoas
# Processing Record 3 of Set 15 | morondava
# Processing Record 4 of Set 15 | chemodanovka
# Processing Record 5 of Set 15 | malinovskiy
# Processing Record 6 of Set 15 | seymchan
# Processing Record 7 of Set 15 | vostok
# Processing Record 8 of Set 15 | necocli
# Processing Record 9 of Set 15 | tshikapa
# Processing Record 10 of Set 15 | neiafu
# Processing Record 11 of Set 15 | manthani
# Processing Record 12 of Set 15 | shiyan
# Processing Record 13 of Set 15 | osa
# Processing Record 14 of Set 15 | ola
# Processing Record 15 of Set 15 | santa rosalia
# Processing Record 16 of Set 15 | fenoarivo
# Processing Record 17 of Set 15 | bonavista
# Processing Record 18 of Set 15 | ventspils
# Processing Record 19 of Set 15 | carauari
# Processing Record 20 of Set 15 | maragogi
# Processing Record 21 of Set 15 | tromso
# Processing Record 22 of Set 15 | porais
# Processing Record 23 of Set 15 | oranjestad
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 666

# %%
# Before exporting your new DataFrame as a CSV file, take a moment to confirm that it looks similar to the image below:
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Goderich  43.7501  -81.7165     57.52        77           7
# 1      Vallenar -28.5708  -70.7581     58.50        68           0
# 2   East London -33.0153   27.9116     60.01        76          10
# 3         Bluff -46.6000  168.3333     49.80        75          99
# 4      Bengkulu  -3.8004  102.2655     80.60        78          93
# 5  Punta Arenas -53.1500  -70.9167     41.11        75          90
# 6      Hermanus -34.4187   19.2345     53.91        83         100
# 7  Saint-Agapit  46.5629  -71.4352     57.47        96          26
# 8          Nehe  48.4833  124.8333     52.63        84         100
# 9          Hilo  19.7297 -155.0900     81.28        91          40
#
#    Wind Speed Weather description
# 0        6.91           clear sky
# 1        1.99           clear sky
# 2        7.11           clear sky
# 3       31.21     overcast clouds
# 4        2.13     overcast clouds
# 5        6.91     overcast clouds
# 6        3.02     overcast clouds
# 7        5.39    scattered clouds
# 8        3.65     overcast clouds
# 9        1.01          light rain

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
