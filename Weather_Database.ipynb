# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | padang
# Processing Record 2 of Set 1 | aguimes
# Processing Record 3 of Set 1 | sarangani
# Processing Record 4 of Set 1 | srednekolymsk
# Processing Record 5 of Set 1 | silver city
# Processing Record 6 of Set 1 | otaru
# Processing Record 7 of Set 1 | salalah
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 1 | coahuayana
# Processing Record 11 of Set 1 | mineral wells
# Processing Record 12 of Set 1 | boke
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | yar-sale
# Processing Record 15 of Set 1 | sitka
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | huarmey
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 1 | port macquarie
# Processing Record 22 of Set 1 | khasan
# Processing Record 23 of Set 1 | hambantota
# Processing Record 24 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 1 | amahai
# Processing Record 26 of Set 1 | bontang
# Processing Record 27 of Set 1 | anadyr
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | pisco
# Processing Record 30 of Set 1 | kenai
# Processing Record 31 of Set 1 | caravelas
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | eureka
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | faanui
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | kirakira
# Processing Record 40 of Set 1 | nyurba
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | pueblo
# Processing Record 45 of Set 1 | broken hill
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | yuci
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | fortuna
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | hasaki
# Processing Record 4 of Set 2 | batemans bay
# Processing Record 5 of Set 2 | ontario
# Processing Record 6 of Set 2 | esperance
# Processing Record 7 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 2 | tabou
# Processing Record 9 of Set 2 | orchard homes
# Processing Record 10 of Set 2 | kodiak
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | souillac
# Processing Record 13 of Set 2 | alakurtti
# Processing Record 14 of Set 2 | ponta do sol
# Processing Record 15 of Set 2 | pokhara
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | oranjemund
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | kem
# Processing Record 20 of Set 2 | francisco sa
# Processing Record 21 of Set 2 | cherskiy
# Processing Record 22 of Set 2 | bastia
# Processing Record 23 of Set 2 | tra vinh
# Processing Record 24 of Set 2 | nanortalik
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | guerrero negro
# Processing Record 27 of Set 2 | korla
# Processing Record 28 of Set 2 | east london
# Processing Record 29 of Set 2 | eyl
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | portland
# Processing Record 33 of Set 2 | westport
# Processing Record 34 of Set 2 | daru
# Processing Record 35 of Set 2 | shubarshi
# Processing Record 36 of Set 2 | gat
# Processing Record 37 of Set 2 | kanye
# Processing Record 38 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 2 | hobyo
# Processing Record 40 of Set 2 | aktau
# Processing Record 41 of Set 2 | horsham
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | beringovskiy
# Processing Record 44 of Set 2 | rikitea
# Processing Record 45 of Set 2 | teahupoo
# Processing Record 46 of Set 2 | flinders
# Processing Record 47 of Set 2 | chuy
# Processing Record 48 of Set 2 | nelson bay
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | hawkesbury
# Processing Record 1 of Set 3 | uzumlu
# City not found. Skipping...
# Processing Record 2 of Set 3 | college
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | katobu
# Processing Record 6 of Set 3 | kaabong
# Processing Record 7 of Set 3 | hovd
# Processing Record 8 of Set 3 | ahipara
# Processing Record 9 of Set 3 | itarema
# Processing Record 10 of Set 3 | ostrovnoy
# Processing Record 11 of Set 3 | nikko
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | jumilla
# Processing Record 14 of Set 3 | nara
# Processing Record 15 of Set 3 | norman wells
# Processing Record 16 of Set 3 | georgetown
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | alice springs
# Processing Record 20 of Set 3 | savannah bight
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | lorengau
# Processing Record 23 of Set 3 | champerico
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | waipawa
# Processing Record 26 of Set 3 | bay city
# Processing Record 27 of Set 3 | teguise
# Processing Record 28 of Set 3 | batabano
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | urumqi
# Processing Record 32 of Set 3 | vostok
# Processing Record 33 of Set 3 | doctor juan leon mallorquin
# Processing Record 34 of Set 3 | vaini
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | rocha
# Processing Record 37 of Set 3 | sungairaya
# Processing Record 38 of Set 3 | zhigansk
# Processing Record 39 of Set 3 | hithadhoo
# Processing Record 40 of Set 3 | karratha
# Processing Record 41 of Set 3 | cape town
# Processing Record 42 of Set 3 | vila velha
# Processing Record 43 of Set 3 | damghan
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | mitsamiouli
# Processing Record 46 of Set 3 | rafaela
# Processing Record 47 of Set 3 | mana
# Processing Record 48 of Set 3 | berezovyy
# Processing Record 49 of Set 3 | buraydah
# Processing Record 50 of Set 3 | bud
# Processing Record 1 of Set 4 | foumban
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | tiarei
# Processing Record 6 of Set 4 | kaitangata
# Processing Record 7 of Set 4 | mahebourg
# Processing Record 8 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | leningradskiy
# Processing Record 11 of Set 4 | kota belud
# Processing Record 12 of Set 4 | qaanaaq
# Processing Record 13 of Set 4 | flin flon
# Processing Record 14 of Set 4 | butaritari
# Processing Record 15 of Set 4 | zhangye
# Processing Record 16 of Set 4 | toropets
# Processing Record 17 of Set 4 | manggar
# Processing Record 18 of Set 4 | hasanpur
# Processing Record 19 of Set 4 | lata
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | estreito
# Processing Record 22 of Set 4 | cururupu
# Processing Record 23 of Set 4 | nizhniy baskunchak
# Processing Record 24 of Set 4 | iqaluit
# Processing Record 25 of Set 4 | fukuma
# Processing Record 26 of Set 4 | bac lieu
# Processing Record 27 of Set 4 | kieta
# Processing Record 28 of Set 4 | ustye
# Processing Record 29 of Set 4 | saint george
# Processing Record 30 of Set 4 | mitu
# Processing Record 31 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 4 | dingle
# Processing Record 33 of Set 4 | bundaberg
# Processing Record 34 of Set 4 | cidreira
# Processing Record 35 of Set 4 | avera
# Processing Record 36 of Set 4 | burica
# City not found. Skipping...
# Processing Record 37 of Set 4 | babina
# Processing Record 38 of Set 4 | havre
# Processing Record 39 of Set 4 | saint anthony
# Processing Record 40 of Set 4 | eskisehir
# Processing Record 41 of Set 4 | pangnirtung
# Processing Record 42 of Set 4 | abay
# Processing Record 43 of Set 4 | kavieng
# Processing Record 44 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 4 | lahaina
# Processing Record 46 of Set 4 | boma
# Processing Record 47 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 4 | ribeira grande
# Processing Record 49 of Set 4 | jamestown
# Processing Record 50 of Set 4 | lagoa
# Processing Record 1 of Set 5 | touros
# Processing Record 2 of Set 5 | longyearbyen
# Processing Record 3 of Set 5 | bengkulu
# Processing Record 4 of Set 5 | presidencia roque saenz pena
# Processing Record 5 of Set 5 | manzhouli
# Processing Record 6 of Set 5 | abhar
# Processing Record 7 of Set 5 | sorland
# Processing Record 8 of Set 5 | provideniya
# Processing Record 9 of Set 5 | komsomolskiy
# Processing Record 10 of Set 5 | cabudare
# Processing Record 11 of Set 5 | cockburn town
# Processing Record 12 of Set 5 | sumbe
# Processing Record 13 of Set 5 | raudeberg
# Processing Record 14 of Set 5 | predivinsk
# Processing Record 15 of Set 5 | rundu
# Processing Record 16 of Set 5 | bossangoa
# Processing Record 17 of Set 5 | laguna
# Processing Record 18 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 5 | sao joao da barra
# Processing Record 20 of Set 5 | bubaque
# Processing Record 21 of Set 5 | rio gallegos
# Processing Record 22 of Set 5 | livingston
# Processing Record 23 of Set 5 | krnov
# Processing Record 24 of Set 5 | ugoofaaru
# Processing Record 25 of Set 5 | kapuskasing
# Processing Record 26 of Set 5 | cap malheureux
# Processing Record 27 of Set 5 | xuddur
# Processing Record 28 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 5 | hobart
# Processing Record 30 of Set 5 | axim
# Processing Record 31 of Set 5 | whitehorse
# Processing Record 32 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 5 | brae
# Processing Record 34 of Set 5 | porto novo
# Processing Record 35 of Set 5 | orlik
# Processing Record 36 of Set 5 | sogdiondon
# City not found. Skipping...
# Processing Record 37 of Set 5 | pajan
# Processing Record 38 of Set 5 | inhambane
# Processing Record 39 of Set 5 | tiksi
# Processing Record 40 of Set 5 | turka
# Processing Record 41 of Set 5 | cabras
# Processing Record 42 of Set 5 | kamenka
# Processing Record 43 of Set 5 | victoria
# Processing Record 44 of Set 5 | upernavik
# Processing Record 45 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 5 | tocache
# Processing Record 47 of Set 5 | praia da vitoria
# Processing Record 48 of Set 5 | marau
# Processing Record 49 of Set 5 | baryshivka
# Processing Record 50 of Set 5 | thompson
# Processing Record 1 of Set 6 | kuching
# Processing Record 2 of Set 6 | kanniyakumari
# Processing Record 3 of Set 6 | maputo
# Processing Record 4 of Set 6 | high level
# Processing Record 5 of Set 6 | mahajanga
# Processing Record 6 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 6 | matara
# Processing Record 8 of Set 6 | ancud
# Processing Record 9 of Set 6 | bonthe
# Processing Record 10 of Set 6 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 11 of Set 6 | narsaq
# Processing Record 12 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 6 | port hedland
# Processing Record 14 of Set 6 | nioro
# Processing Record 15 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 6 | ulety
# Processing Record 17 of Set 6 | marfino
# Processing Record 18 of Set 6 | alamosa
# Processing Record 19 of Set 6 | sorong
# Processing Record 20 of Set 6 | empangeni
# Processing Record 21 of Set 6 | mayo
# Processing Record 22 of Set 6 | gazojak
# Processing Record 23 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 24 of Set 6 | hamilton
# Processing Record 25 of Set 6 | dunedin
# Processing Record 26 of Set 6 | rorvik
# Processing Record 27 of Set 6 | saint-joseph
# Processing Record 28 of Set 6 | grindavik
# Processing Record 29 of Set 6 | hofn
# Processing Record 30 of Set 6 | puerto suarez
# Processing Record 31 of Set 6 | dubbo
# Processing Record 32 of Set 6 | vila franca do campo
# Processing Record 33 of Set 6 | avarua
# Processing Record 34 of Set 6 | sechura
# Processing Record 35 of Set 6 | nantucket
# Processing Record 36 of Set 6 | bograd
# Processing Record 37 of Set 6 | manicore
# Processing Record 38 of Set 6 | clyde river
# Processing Record 39 of Set 6 | natal
# Processing Record 40 of Set 6 | tautira
# Processing Record 41 of Set 6 | bitterfeld
# Processing Record 42 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 6 | griffith
# Processing Record 44 of Set 6 | naze
# Processing Record 45 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 6 | zhezkazgan
# Processing Record 47 of Set 6 | camopi
# Processing Record 48 of Set 6 | koshurnikovo
# Processing Record 49 of Set 6 | mirabad
# Processing Record 50 of Set 6 | chuguyevka
# Processing Record 1 of Set 7 | wangqing
# Processing Record 2 of Set 7 | omboue
# Processing Record 3 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 4 of Set 7 | vardo
# Processing Record 5 of Set 7 | bitung
# Processing Record 6 of Set 7 | nassogne
# Processing Record 7 of Set 7 | saint andrews
# Processing Record 8 of Set 7 | te anau
# Processing Record 9 of Set 7 | haapiti
# Processing Record 10 of Set 7 | diego de almagro
# Processing Record 11 of Set 7 | kalabo
# Processing Record 12 of Set 7 | salzwedel
# Processing Record 13 of Set 7 | bathsheba
# Processing Record 14 of Set 7 | mangrol
# Processing Record 15 of Set 7 | lompoc
# Processing Record 16 of Set 7 | torbay
# Processing Record 17 of Set 7 | aklavik
# Processing Record 18 of Set 7 | abbeville
# Processing Record 19 of Set 7 | riviere-au-renard
# Processing Record 20 of Set 7 | ussel
# Processing Record 21 of Set 7 | matelica
# Processing Record 22 of Set 7 | camargo
# Processing Record 23 of Set 7 | salima
# Processing Record 24 of Set 7 | haines junction
# Processing Record 25 of Set 7 | doha
# Processing Record 26 of Set 7 | the valley
# Processing Record 27 of Set 7 | nouadhibou
# Processing Record 28 of Set 7 | nancha
# Processing Record 29 of Set 7 | chaykovskiy
# Processing Record 30 of Set 7 | samarai
# Processing Record 31 of Set 7 | atar
# Processing Record 32 of Set 7 | todos santos
# Processing Record 33 of Set 7 | carutapera
# Processing Record 34 of Set 7 | atikokan
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | sur
# Processing Record 37 of Set 7 | nemuro
# Processing Record 38 of Set 7 | mayachnyy
# Processing Record 39 of Set 7 | taoudenni
# Processing Record 40 of Set 7 | evensk
# Processing Record 41 of Set 7 | ludvika
# Processing Record 42 of Set 7 | san quintin
# Processing Record 43 of Set 7 | roma
# Processing Record 44 of Set 7 | isla mujeres
# Processing Record 45 of Set 7 | tarbagatay
# Processing Record 46 of Set 7 | mae hong son
# Processing Record 47 of Set 7 | roros
# Processing Record 48 of Set 7 | sayyan
# Processing Record 49 of Set 7 | ilulissat
# Processing Record 50 of Set 7 | dukat
# Processing Record 1 of Set 8 | obluche
# City not found. Skipping...
# Processing Record 2 of Set 8 | fairbanks
# Processing Record 3 of Set 8 | levanger
# Processing Record 4 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 5 of Set 8 | sanary-sur-mer
# Processing Record 6 of Set 8 | tuatapere
# Processing Record 7 of Set 8 | methoni
# Processing Record 8 of Set 8 | kruisfontein
# Processing Record 9 of Set 8 | cedar city
# Processing Record 10 of Set 8 | egvekinot
# Processing Record 11 of Set 8 | pascagoula
# Processing Record 12 of Set 8 | heihe
# Processing Record 13 of Set 8 | vestmannaeyjar
# Processing Record 14 of Set 8 | mocoa
# Processing Record 15 of Set 8 | clarence town
# Processing Record 16 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 17 of Set 8 | sinnamary
# Processing Record 18 of Set 8 | bjornevatn
# Processing Record 19 of Set 8 | tikrit
# Processing Record 20 of Set 8 | nagato
# Processing Record 21 of Set 8 | san patricio
# Processing Record 22 of Set 8 | bend
# Processing Record 23 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 8 | luganville
# Processing Record 25 of Set 8 | salym
# Processing Record 26 of Set 8 | tazovskiy
# Processing Record 27 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 28 of Set 8 | marsa matruh
# Processing Record 29 of Set 8 | kaka
# Processing Record 30 of Set 8 | ust-koksa
# Processing Record 31 of Set 8 | mnogovershinnyy
# Processing Record 32 of Set 8 | leshukonskoye
# Processing Record 33 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 8 | alofi
# Processing Record 35 of Set 8 | mehamn
# Processing Record 36 of Set 8 | sibu
# Processing Record 37 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 8 | margate
# Processing Record 40 of Set 8 | miandrivazo
# Processing Record 41 of Set 8 | pendleton
# Processing Record 42 of Set 8 | zyryanka
# Processing Record 43 of Set 8 | saldanha
# Processing Record 44 of Set 8 | mogadishu
# Processing Record 45 of Set 8 | olafsvik
# Processing Record 46 of Set 8 | imbituba
# Processing Record 47 of Set 8 | fairhope
# Processing Record 48 of Set 8 | nuuk
# Processing Record 49 of Set 8 | manaure
# Processing Record 50 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 9 | havre-saint-pierre
# Processing Record 2 of Set 9 | caraballeda
# Processing Record 3 of Set 9 | seoul
# Processing Record 4 of Set 9 | ofaqim
# Processing Record 5 of Set 9 | japura
# Processing Record 6 of Set 9 | caxito
# Processing Record 7 of Set 9 | prainha
# Processing Record 8 of Set 9 | atambua
# Processing Record 9 of Set 9 | valenza
# Processing Record 10 of Set 9 | dolores
# Processing Record 11 of Set 9 | gayeri
# Processing Record 12 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 9 | kristianstad
# Processing Record 14 of Set 9 | archidona
# Processing Record 15 of Set 9 | biak
# Processing Record 16 of Set 9 | paso de los toros
# Processing Record 17 of Set 9 | gorban
# Processing Record 18 of Set 9 | pacific grove
# Processing Record 19 of Set 9 | vagur
# Processing Record 20 of Set 9 | humaita
# Processing Record 21 of Set 9 | suntar
# Processing Record 22 of Set 9 | constitucion
# Processing Record 23 of Set 9 | jalesar
# Processing Record 24 of Set 9 | kodinsk
# Processing Record 25 of Set 9 | toora-khem
# Processing Record 26 of Set 9 | calais
# Processing Record 27 of Set 9 | quepos
# Processing Record 28 of Set 9 | sola
# Processing Record 29 of Set 9 | mmabatho
# Processing Record 30 of Set 9 | port augusta
# Processing Record 31 of Set 9 | cayenne
# Processing Record 32 of Set 9 | ust-ilimsk
# Processing Record 33 of Set 9 | port lincoln
# Processing Record 34 of Set 9 | bandarbeyla
# Processing Record 35 of Set 9 | tayu
# Processing Record 36 of Set 9 | entre rios
# Processing Record 37 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 38 of Set 9 | acapulco
# Processing Record 39 of Set 9 | arlit
# Processing Record 40 of Set 9 | sabla
# Processing Record 41 of Set 9 | juneau
# Processing Record 42 of Set 9 | mwene-ditu
# Processing Record 43 of Set 9 | san andres
# Processing Record 44 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 9 | berdigestyakh
# Processing Record 46 of Set 9 | novogornyy
# Processing Record 47 of Set 9 | mokrousovo
# Processing Record 48 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 50 of Set 9 | coruripe
# Processing Record 1 of Set 10 | rongcheng
# Processing Record 2 of Set 10 | agadez
# Processing Record 3 of Set 10 | marawi
# Processing Record 4 of Set 10 | acajutla
# Processing Record 5 of Set 10 | santarem
# Processing Record 6 of Set 10 | fort frances
# Processing Record 7 of Set 10 | darhan
# Processing Record 8 of Set 10 | novyy urengoy
# Processing Record 9 of Set 10 | grand valley
# Processing Record 10 of Set 10 | husavik
# Processing Record 11 of Set 10 | micheweni
# Processing Record 12 of Set 10 | zvishavane
# Processing Record 13 of Set 10 | aykhal
# Processing Record 14 of Set 10 | sukumo
# Processing Record 15 of Set 10 | isangel
# Processing Record 16 of Set 10 | bambanglipuro
# Processing Record 17 of Set 10 | malkara
# Processing Record 18 of Set 10 | athabasca
# Processing Record 19 of Set 10 | iisaku
# Processing Record 20 of Set 10 | broome
# Processing Record 21 of Set 10 | laela
# Processing Record 22 of Set 10 | simbahan
# Processing Record 23 of Set 10 | bolzano
# Processing Record 24 of Set 10 | worthington
# Processing Record 25 of Set 10 | solnechnyy
# Processing Record 26 of Set 10 | edd
# Processing Record 27 of Set 10 | west odessa
# Processing Record 28 of Set 10 | mount isa
# Processing Record 29 of Set 10 | garowe
# Processing Record 30 of Set 10 | panalingaan
# Processing Record 31 of Set 10 | waingapu
# Processing Record 32 of Set 10 | okhotsk
# Processing Record 33 of Set 10 | biggar
# Processing Record 34 of Set 10 | jumla
# Processing Record 35 of Set 10 | palimbang
# Processing Record 36 of Set 10 | muli
# Processing Record 37 of Set 10 | lasa
# Processing Record 38 of Set 10 | tateyama
# Processing Record 39 of Set 10 | nacala
# Processing Record 40 of Set 10 | sakakah
# Processing Record 41 of Set 10 | bulawayo
# Processing Record 42 of Set 10 | ketchikan
# Processing Record 43 of Set 10 | umm lajj
# Processing Record 44 of Set 10 | catuday
# Processing Record 45 of Set 10 | akdepe
# Processing Record 46 of Set 10 | krasnoselkup
# Processing Record 47 of Set 10 | plettenberg bay
# Processing Record 48 of Set 10 | yerbogachen
# Processing Record 49 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 50 of Set 10 | chiang khong
# Processing Record 1 of Set 11 | hervey bay
# Processing Record 2 of Set 11 | santa isabel do rio negro
# Processing Record 3 of Set 11 | kahului
# Processing Record 4 of Set 11 | talavera de la reina
# Processing Record 5 of Set 11 | mount pleasant
# Processing Record 6 of Set 11 | sanmenxia
# Processing Record 7 of Set 11 | lucea
# Processing Record 8 of Set 11 | vorozhba
# Processing Record 9 of Set 11 | puerto leguizamo
# Processing Record 10 of Set 11 | qaqortoq
# Processing Record 11 of Set 11 | higuey
# City not found. Skipping...
# Processing Record 12 of Set 11 | poum
# Processing Record 13 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 11 | ornskoldsvik
# Processing Record 15 of Set 11 | west wendover
# Processing Record 16 of Set 11 | praya
# Processing Record 17 of Set 11 | pauini
# Processing Record 18 of Set 11 | sindon
# Processing Record 19 of Set 11 | verkhnyaya inta
# Processing Record 20 of Set 11 | trinidad
# Processing Record 21 of Set 11 | moose factory
# Processing Record 22 of Set 11 | marsh harbour
# Processing Record 23 of Set 11 | grabovo
# Processing Record 24 of Set 11 | tres picos
# Processing Record 25 of Set 11 | copiapo
# Processing Record 26 of Set 11 | darnah
# Processing Record 27 of Set 11 | grootfontein
# Processing Record 28 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 11 | saint-pierre
# Processing Record 30 of Set 11 | la paz
# Processing Record 31 of Set 11 | ulaangom
# Processing Record 32 of Set 11 | mount gambier
# Processing Record 33 of Set 11 | shenjiamen
# Processing Record 34 of Set 11 | repelon
# Processing Record 35 of Set 11 | gravdal
# Processing Record 36 of Set 11 | buala
# Processing Record 37 of Set 11 | mapiripan
# Processing Record 38 of Set 11 | uhlove
# Processing Record 39 of Set 11 | ural
# Processing Record 40 of Set 11 | pedasi
# Processing Record 41 of Set 11 | beloha
# Processing Record 42 of Set 11 | mahina
# Processing Record 43 of Set 11 | paka
# Processing Record 44 of Set 11 | buchanan
# Processing Record 45 of Set 11 | riyadh
# Processing Record 46 of Set 11 | abu samrah
# Processing Record 47 of Set 11 | port-gentil
# Processing Record 48 of Set 11 | fort nelson
# Processing Record 49 of Set 11 | jaque
# Processing Record 50 of Set 11 | iracoubo
# Processing Record 1 of Set 12 | yamoussoukro
# Processing Record 2 of Set 12 | iskitim
# Processing Record 3 of Set 12 | hit
# Processing Record 4 of Set 12 | chabahar
# Processing Record 5 of Set 12 | latung
# Processing Record 6 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 12 | miramar
# Processing Record 8 of Set 12 | qasigiannguit
# Processing Record 9 of Set 12 | satipo
# Processing Record 10 of Set 12 | saurimo
# Processing Record 11 of Set 12 | puerto del rosario
# Processing Record 12 of Set 12 | gizo
# Processing Record 13 of Set 12 | bogotol
# Processing Record 14 of Set 12 | yerofey pavlovich
# Processing Record 15 of Set 12 | kroya
# Processing Record 16 of Set 12 | kumano
# Processing Record 17 of Set 12 | nalut
# Processing Record 18 of Set 12 | belyy yar
# Processing Record 19 of Set 12 | zolochiv
# Processing Record 20 of Set 12 | road town
# Processing Record 21 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 12 | houma
# Processing Record 23 of Set 12 | namibe
# Processing Record 24 of Set 12 | port blair
# Processing Record 25 of Set 12 | diamantino
# Processing Record 26 of Set 12 | barabash
# Processing Record 27 of Set 12 | fare
# Processing Record 28 of Set 12 | sao gabriel da cachoeira
# Processing Record 29 of Set 12 | matagami
# Processing Record 30 of Set 12 | pervomayskoye
# Processing Record 31 of Set 12 | roald
# Processing Record 32 of Set 12 | pachino
# Processing Record 33 of Set 12 | kapoeta
# Processing Record 34 of Set 12 | los llanos de aridane
# Processing Record 35 of Set 12 | kempsey
# Processing Record 36 of Set 12 | vila
# Processing Record 37 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 12 | sobolevo
# Processing Record 39 of Set 12 | banda aceh
# Processing Record 40 of Set 12 | yaring
# Processing Record 41 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 12 | roebourne
# Processing Record 44 of Set 12 | effingham
# Processing Record 45 of Set 12 | ouricuri
# Processing Record 46 of Set 12 | maromitsa
# Processing Record 47 of Set 12 | chernyshevskiy
# Processing Record 48 of Set 12 | malindi
# Processing Record 49 of Set 12 | coromandel
# Processing Record 50 of Set 12 | ranong
# Processing Record 1 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 13 | pakxan
# Processing Record 3 of Set 13 | wajir
# Processing Record 4 of Set 13 | luwuk
# Processing Record 5 of Set 13 | ponta delgada
# Processing Record 6 of Set 13 | hami
# Processing Record 7 of Set 13 | taicheng
# Processing Record 8 of Set 13 | lyngseidet
# Processing Record 9 of Set 13 | gamba
# Processing Record 10 of Set 13 | suoyarvi
# Processing Record 11 of Set 13 | shimoda
# Processing Record 12 of Set 13 | katsuura
# Processing Record 13 of Set 13 | puerto baquerizo moreno
# Processing Record 14 of Set 13 | bam
# Processing Record 15 of Set 13 | uyuni
# Processing Record 16 of Set 13 | tshane
# Processing Record 17 of Set 13 | cansilayan
# Processing Record 18 of Set 13 | warrington
# Processing Record 19 of Set 13 | yokadouma
# Processing Record 20 of Set 13 | lavrentiya
# Processing Record 21 of Set 13 | issenye
# Processing Record 22 of Set 13 | ola
# Processing Record 23 of Set 13 | ust-omchug
# Processing Record 24 of Set 13 | vila do maio
# Processing Record 25 of Set 13 | surgut
# Processing Record 26 of Set 13 | chifeng
# Processing Record 27 of Set 13 | muisne
# Processing Record 28 of Set 13 | callaguip
# Processing Record 29 of Set 13 | araguaina
# Processing Record 30 of Set 13 | warri
# Processing Record 31 of Set 13 | santa cruz de la palma
# Processing Record 32 of Set 13 | ryotsu
# Processing Record 33 of Set 13 | uulu
# Processing Record 34 of Set 13 | nampa
# Processing Record 35 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 13 | morondava
# Processing Record 37 of Set 13 | vyartsilya
# Processing Record 38 of Set 13 | larkhall
# Processing Record 39 of Set 13 | sao miguel do araguaia
# Processing Record 40 of Set 13 | berlevag
# Processing Record 41 of Set 13 | vanimo
# Processing Record 42 of Set 13 | uusikaupunki
# Processing Record 43 of Set 13 | henties bay
# Processing Record 44 of Set 13 | alvorada
# Processing Record 45 of Set 13 | bilma
# Processing Record 46 of Set 13 | ouegoa
# Processing Record 47 of Set 13 | udachnyy
# Processing Record 48 of Set 13 | vao
# Processing Record 49 of Set 13 | deputatskiy
# Processing Record 50 of Set 13 | morehead
# Processing Record 1 of Set 14 | kulhudhuffushi
# Processing Record 2 of Set 14 | noumea
# Processing Record 3 of Set 14 | shizukuishi
# Processing Record 4 of Set 14 | brigantine
# Processing Record 5 of Set 14 | chumikan
# Processing Record 6 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 14 | bodmin
# Processing Record 8 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 9 of Set 14 | yenagoa
# Processing Record 10 of Set 14 | walvis bay
# Processing Record 11 of Set 14 | elat
# Processing Record 12 of Set 14 | brokopondo
# Processing Record 13 of Set 14 | ozernovskiy
# Processing Record 14 of Set 14 | talara
# Processing Record 15 of Set 14 | umm kaddadah
# Processing Record 16 of Set 14 | sangar
# Processing Record 17 of Set 14 | zadar
# Processing Record 18 of Set 14 | lucapa
# Processing Record 19 of Set 14 | birao
# Processing Record 20 of Set 14 | kilmez
# City not found. Skipping...
# Processing Record 21 of Set 14 | umm jarr
# City not found. Skipping...
# Processing Record 22 of Set 14 | san policarpo
# Processing Record 23 of Set 14 | wilmington
# Processing Record 24 of Set 14 | meulaboh
# Processing Record 25 of Set 14 | iranshahr
# Processing Record 26 of Set 14 | rio cuarto
# Processing Record 27 of Set 14 | bilibino
# Processing Record 28 of Set 14 | antofagasta
# Processing Record 29 of Set 14 | iralaya
# Processing Record 30 of Set 14 | bell ville
# Processing Record 31 of Set 14 | palana
# Processing Record 32 of Set 14 | rio grande
# Processing Record 33 of Set 14 | aksu
# Processing Record 34 of Set 14 | alta floresta
# Processing Record 35 of Set 14 | tibati
# Processing Record 36 of Set 14 | baykit
# Processing Record 37 of Set 14 | mananjary
# Processing Record 38 of Set 14 | bratsk
# Processing Record 39 of Set 14 | nome
# Processing Record 40 of Set 14 | niteroi
# Processing Record 41 of Set 14 | perigueux
# Processing Record 42 of Set 14 | ciudad bolivar
# Processing Record 43 of Set 14 | bitkine
# Processing Record 44 of Set 14 | yulara
# Processing Record 45 of Set 14 | knysna
# Processing Record 46 of Set 14 | limoges
# Processing Record 47 of Set 14 | joao neiva
# Processing Record 48 of Set 14 | lyndon
# Processing Record 49 of Set 14 | oneonta
# Processing Record 50 of Set 14 | terenos
# Processing Record 1 of Set 15 | svendborg
# Processing Record 2 of Set 15 | phan thiet
# Processing Record 3 of Set 15 | kushmurun
# Processing Record 4 of Set 15 | kokopo
# Processing Record 5 of Set 15 | enkoping
# Processing Record 6 of Set 15 | helong
# Processing Record 7 of Set 15 | nortelandia
# Processing Record 8 of Set 15 | praia
# Processing Record 9 of Set 15 | baruun-urt
# Processing Record 10 of Set 15 | araguacu
# Processing Record 11 of Set 15 | teya
# Processing Record 12 of Set 15 | kharp
# Processing Record 13 of Set 15 | stornoway
# Processing Record 14 of Set 15 | adrar
# Processing Record 15 of Set 15 | gushikawa
# Processing Record 16 of Set 15 | general roca
# Processing Record 17 of Set 15 | gorkovskoye
# City not found. Skipping...
# Processing Record 18 of Set 15 | rudnogorsk
# Processing Record 19 of Set 15 | lodja
# Processing Record 20 of Set 15 | abnub
# Processing Record 21 of Set 15 | edea
# Processing Record 22 of Set 15 | beira
# Processing Record 23 of Set 15 | kamaishi
# Processing Record 24 of Set 15 | altay
# Processing Record 25 of Set 15 | borgarnes
# Processing Record 26 of Set 15 | sao luis
# Processing Record 27 of Set 15 | gudari
# Processing Record 28 of Set 15 | luderitz
# Processing Record 29 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 15 | fomboni
# Processing Record 31 of Set 15 | salinopolis
# Processing Record 32 of Set 15 | lerwick
# Processing Record 33 of Set 15 | ca mau
# Processing Record 34 of Set 15 | redlands
# Processing Record 35 of Set 15 | san javier
# Processing Record 36 of Set 15 | tigil
# Processing Record 37 of Set 15 | ahuimanu
# Processing Record 38 of Set 15 | strezhevoy
# Processing Record 39 of Set 15 | bismarck
# Processing Record 40 of Set 15 | carauari
# Processing Record 41 of Set 15 | kargasok
# Processing Record 42 of Set 15 | tessalit
# Processing Record 43 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 15 | les cayes
# Processing Record 45 of Set 15 | timra
# Processing Record 46 of Set 15 | zemio
# Processing Record 47 of Set 15 | cooma
# Processing Record 48 of Set 15 | ibia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# Before exporting your new DataFrame as a CSV file, take a moment to confirm that it looks similar to the image below:
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Padang      ID  -0.9492  100.3543     83.82        73          95
# 1        Aguimes      ES  27.9054  -15.4461     68.63        69          40
# 2      Sarangani      PH   5.4033  125.4636     81.25        78         100
# 3  Srednekolymsk      RU  67.4500  153.6833     42.57        58         100
# 4    Silver City      US  32.7701 -108.2803     65.91        68          40
# 5          Otaru      JP  43.1894  141.0022     69.42        55           4
# 6        Salalah      OM  17.0151   54.0924     82.49        78          75
# 7    Tuktoyaktuk      CA  69.4541 -133.0374     33.80       100          90
# 8     Coahuayana      MX  18.7333 -103.6833     78.57        92          92
# 9  Mineral Wells      US  32.8085  -98.1128     77.92        46           1
#
#    Wind Speed      Weather description
# 0        3.76          overcast clouds
# 1       10.36         scattered clouds
# 2       14.38          overcast clouds
# 3       11.95          overcast clouds
# 4        6.91         scattered clouds
# 5        5.28                clear sky
# 6        3.44            broken clouds
# 7       18.41  light intensity drizzle
# 8        0.34          overcast clouds
# 9        8.05                clear sky

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "Vacation_Search/WeatherPy_vacation.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
